# %% [markdown]
# # Periodic Hill -- Re = 5600

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
matplotlib.rc('xtick', labelsize=25) 
matplotlib.rc('ytick', labelsize=25)

font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 25}

matplotlib.rc('font', **font)

# %%
hill = np.loadtxt('/home/unimelb.edu.au/lcampoli/UoM/Testcases/PeriodicHill/02_Data/hill.txt')

# %%
# https://www.kbwiki.ercoftac.org/w/index.php/UFR_3-30_Test_Case#Curvilinear_grids_2
dir = '/home/unimelb.edu.au/lcampoli/UoM/Testcases/PeriodicHill/02_Data/'

Re=700

p001 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-001.dat') 
p002 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-002.dat') 
p003 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-003.dat') 
p004 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-004.dat') 
p005 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-005.dat') 
p006 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-006.dat') 
p007 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-007.dat') 
p008 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-008.dat') 
p009 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-009.dat') 
p010 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-010.dat') 

DNS_700 = [p001, p003, p004, p005, p006, p007, p008, p009, p010]

Re=1400

p001 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-001.dat') 
p002 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-002.dat') 
p003 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-003.dat') 
p004 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-004.dat') 
p005 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-005.dat') 
p006 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-006.dat') 
p007 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-007.dat') 
p008 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-008.dat') 
p009 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-009.dat') 
p010 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-010.dat') 

DNS_1400 = [p001, p003, p004, p005, p006, p007, p008, p009, p010]

Re=2800

p001 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-001.dat') 
p002 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-002.dat') 
p003 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-003.dat') 
p004 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-004.dat') 
p005 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-005.dat') 
p006 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-006.dat') 
p007 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-007.dat') 
p008 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-008.dat') 
p009 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-009.dat') 
p010 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-010.dat') 

DNS_2800 = [p001, p003, p004, p005, p006, p007, p008, p009, p010]

Re=5600

p001 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-001.dat') 
p002 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-002.dat') 
p003 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-003.dat') 
p004 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-004.dat') 
p005 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-005.dat') 
p006 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-006.dat') 
p007 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-007.dat') 
p008 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-008.dat') 
p009 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-009.dat') 
p010 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-010.dat') 

DNS_5600 = [p001, p003, p004, p005, p006, p007, p008, p009, p010]

Re=10595

p001 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-001.dat') 
p002 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-002.dat') 
p003 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-003.dat') 
p004 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-004.dat') 
p005 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-005.dat') 
p006 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-006.dat') 
p007 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-007.dat') 
p008 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-008.dat') 
p009 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-009.dat') 
p010 = np.loadtxt(dir+'Re_'+str(Re)+'/UFR3-30TestCase/UFR3-30_C_'+str(Re)+'_data_MB-010.dat') 

LES_10595 = [p001, p003, p004, p005, p006, p007, p008, p009, p010]

# %%
Re=10595

p001 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-001.dat') 
p002 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-002.dat') 
p003 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-003.dat') 
p004 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-004.dat') 
p005 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-005.dat') 
p006 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-006.dat') 
p007 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-007.dat') 
p008 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-008.dat') 
p009 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-009.dat') 
p010 = np.loadtxt(dir+'Re_'+str(Re)+'/LES_by_Temmerman_and_Leschziner/data-010.dat') 

LES_10595_TL = [p001, p003, p004, p005, p006, p007, p008, p009, p010]

# %%
edir = '/home/unimelb.edu.au/lcampoli/UoM/Testcases/PeriodicHill/02_Data/'

Re=5600

e001 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-001.dat', skiprows=6, delimiter=',') #0.05
e002 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-002.dat', skiprows=6, delimiter=',') #0.5
e003 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-003.dat', skiprows=6, delimiter=',') #1
e004 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-004.dat', skiprows=6, delimiter=',') #2
e005 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-005.dat', skiprows=6, delimiter=',') #3
e006 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-006.dat', skiprows=6, delimiter=',') #4
e007 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-007.dat', skiprows=6, delimiter=',') #5
e008 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-008.dat', skiprows=6, delimiter=',') #6
e009 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-009.dat', skiprows=6, delimiter=',') #7
e010 = np.loadtxt(dir+'Re_'+str(Re)+'/Exp_Re_'+str(Re)+'/UFR3-30_X_'+str(Re)+'_data_CR-010.dat', skiprows=6, delimiter=',') #8

EXP_5600 = [e001, e003, e004, e005, e006, e007, e008, e009, e010]

# %%
dir = '../pehill-5-cases-DNS/case_1p0_refined/dns-data/'
mean_files = np.loadtxt(dir+'mean_files.dat')

# %% [markdown]
# ### These two solutions below just check to be equal when using different versions of OF

# %%
path = 'case_1p0_refined_kOmegaSST_OF23/postProcessing/sets/25000/'
RANS_kOmegaSST_OF23_U = []
RANS_kOmegaSST_OF23_R = []
for f in range(0,9):
    RANS_kOmegaSST_OF23_U.append(np.loadtxt(path+'line_x'+str(f)+'_U.xy'))
    RANS_kOmegaSST_OF23_R.append(np.loadtxt(path+'line_x'+str(f)+'_R.xy'))

# %%
path = 'case_1p0_refined_kOmegaSST_OF7/postProcessing/sampleDict/25000/'
RANS_kOmegaSST_OF7_U = []
RANS_kOmegaSST_OF7_R = []
for f in range(0,9):
    RANS_kOmegaSST_OF7_U.append(np.loadtxt(path+'line_x'+str(f)+'_U.xy'))
    RANS_kOmegaSST_OF7_R.append(np.loadtxt(path+'line_x'+str(f)+'_R.xy'))

# %% [markdown]
# ### This solution is the one obtained with the model present in the original test case

# %%
path = 'case_1p0_refined_LaunderSharmaKE/postProcessing/sets/25000/'
RANS_LaunderSharmaKE_U = []
RANS_LaunderSharmaKE_R = []
for f in range(0,9):
    RANS_LaunderSharmaKE_U.append(np.loadtxt(path+'line_x'+str(f)+'_U.xy'))
    RANS_LaunderSharmaKE_R.append(np.loadtxt(path+'line_x'+str(f)+'_R.xy'))

# %% [markdown]
# ### This is the DNS solution mapped onto the RANS domain (reference)

# %%
path = 'case_1p0_refined/postProcessing/sampleDict/10000/'
DNS2RANS_U = []
DNS2RANS_R = []
for f in range(0,9):
    DNS2RANS_U.append(np.loadtxt(path+'line_x'+str(f)+'_UDNS.xy'))
    DNS2RANS_R.append(np.loadtxt(path+'line_x'+str(f)+'_TauDNS.xy'))

# %% [markdown]
# ### This is the RANS solution from the original case_1p0_refined folder

# %%
path = 'case_1p0_refined/postProcessing/sampleDict/25000/'
RANS_U = []
RANS_R = []
RANS_K = []
for f in range(0,9):
    RANS_U.append(np.loadtxt(path+'line_x'+str(f)+'_U.xy'))
    RANS_R.append(np.loadtxt(path+'line_x'+str(f)+'_R.xy'))
    RANS_K.append(np.loadtxt(path+'line_x'+str(f)+'_k.xy'))

# %% [markdown]
# ### Comparison of DNS, LES, RANS and EXP results

# %%
plt.figure(figsize=(30,15), frameon=False)
plt.axhline(y = 3.05, xmin=0, xmax=9, color = 'lightgrey', linestyle = 'dotted', linewidth=5)
plt.plot(hill[:,0], hill[:,1], label='PH', linewidth=5, c='lightgrey', linestyle = '-')

ub=0.0569869/2 
print("Bulk velocity integrated over the inlet section =",ub)
fac=1/ub
lw = 5 

for f in range(0,9):
    
    # Experimental data
    plt.scatter(EXP_5600[f][:,1]+f,                EXP_5600[f][:,0],               c='k',      linewidth=10, label='EXP', marker='.')
    
    # DNS results
    #plt.plot(fac*DNS_700[f][:,1]+f,               DNS_700[f][:,0],                c='m',      linewidth=3,  label='Re_700')
    #plt.plot(fac*DNS_1400[f][:,1]+f,              DNS_1400[f][:,0],               c='b',      linewidth=3,  label='Re_1400')
    #plt.plot(fac*DNS_2800[f][:,1]+f,              DNS_2800[f][:,0],               c='lime',   linewidth=3,  label='Re_2800')
    plt.plot(DNS_5600[f][:,1]+f,                   DNS_5600[f][:,0],               c='k',      linewidth=lw, label='Re_5600')
    #plt.plot(fac*LES_10595[f][:,1]+f,             LES_10595[f][:,0],              c='k',      linewidth=3,  label='Re_10595')
    
    # DNS mapped onto RANS domain
    plt.plot(fac*DNS2RANS_U[f][:,1]+f,             DNS2RANS_U[f][:,0],             c='lime',   linewidth=3,  label='DNS2RANS') 
    
    # RANS solutions
    plt.plot(fac*RANS_U[f][:,1]+f,                 RANS_U[f][:,0],                 c='r',      linewidth=lw, label='RANS no inlet profiles')
    plt.plot(fac*RANS_LaunderSharmaKE_U[f][:,1]+f, RANS_LaunderSharmaKE_U[f][:,0], c='b',      linewidth=lw, label='RANS_LaunderSharmaKE')
    plt.plot(fac*RANS_kOmegaSST_OF7_U[f][:,1]+f,   RANS_kOmegaSST_OF7_U[f][:,0],   c='m',      linewidth=lw, label='RANS_kOmegaSST')    
    
plt.xticks(np.arange(0, 10, step=1))
plt.ylabel("$y/H$ [-]")
plt.xlabel("$U/u_{b} + x/H$ [-]")
plt.tight_layout()
#plt.legend(['top', 'bottom', 'Re_700', 'Re_1400', 'Re_2800', 'Re_5600', 'Re_10595'], loc='lower right')
plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS_kOmegaSST no inlet profiles', 'RANS_LaunderSharmaKE', 'RANS_kOmegaSST'], loc='lower right')
plt.grid()
plt.show()
plt.close()
# Out:
# Bulk velocity integrated over the inlet section = 0.02849345

# %%
plt.figure(figsize=(30,15), frameon=False)
plt.axhline(y = 3.05, xmin=0, xmax=9, color = 'lightgrey', linestyle = 'dotted', linewidth=5)
plt.plot(hill[:,0], hill[:,1], label='PH', linewidth=5, c='lightgrey', linestyle = '-')

ub=0.0569869/2 
print("Bulk velocity integrated over the inlet section =",ub)
fac=1/ub
pre=5
lw = 5 

for f in range(0,9):
    
    # Experimental data
    plt.scatter(pre*EXP_5600[f][:,2]+f,                EXP_5600[f][:,0],     c='k',      linewidth=10, label='EXP', marker='.')
    
    # DNS results
    #plt.plot(fac*DNS_700[f][:,2]+f,                   DNS_700[f][:,0],      c='m',      linewidth=3,  label='Re_700')
    #plt.plot(fac*DNS_1400[f][:,2]+f,                  DNS_1400[f][:,0],     c='b',      linewidth=3,  label='Re_1400')
    #plt.plot(fac*DNS_2800[f][:,2]+f,                  DNS_2800[f][:,0],     c='lime',   linewidth=3,  label='Re_2800')
    plt.plot(pre*DNS_5600[f][:,2]+f,                   DNS_5600[f][:,0],     c='k',      linewidth=lw, label='Re_5600')
    #plt.plot(fac*LES_10595[f][:,2]+f,                 LES_10595[f][:,0],              c='k',      linewidth=3,  label='Re_10595')
    
    # DNS mapped onto RANS domain
    plt.plot(pre*fac*DNS2RANS_U[f][:,2]+f,             DNS2RANS_U[f][:,0],             c='lime',   linewidth=3,  label='DNS2RANS') 
    
    # RANS solutions
    plt.plot(pre*fac*RANS_U[f][:,2]+f,                 RANS_U[f][:,0],                 c='r',      linewidth=lw, label='RANS no inlet profiles') 
    plt.plot(pre*fac*RANS_LaunderSharmaKE_U[f][:,2]+f, RANS_LaunderSharmaKE_U[f][:,0], c='b',      linewidth=lw, label='RANS_LaunderSharmaKE')
    plt.plot(pre*fac*RANS_kOmegaSST_OF7_U[f][:,2]+f,   RANS_kOmegaSST_OF7_U[f][:,0],   c='m',      linewidth=lw, label='RANS_kOmegaSST')    
    
plt.xticks(np.arange(0, 10, step=1))
plt.ylabel("$y/H$ [-]")
plt.xlabel("$V/u_{b} + x/H$ [-]")
plt.tight_layout()
#plt.legend(['top', 'bottom', 'Re_700', 'Re_1400', 'Re_2800', 'Re_5600', 'Re_10595'], loc='lower right')
#plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS'], loc='lower right')
plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS_kOmegaSST no inlet profiles', 'RANS_LaunderSharmaKE', 'RANS_kOmegaSST'], loc='lower right')
plt.grid()
plt.show()
plt.close()
# Out:
# Bulk velocity integrated over the inlet section = 0.02849345

# %%
plt.figure(figsize=(30,15), frameon=False)
plt.axhline(y = 3.05, xmin=0, xmax=9, color = 'lightgrey', linestyle = 'dotted', linewidth=5)
plt.plot(hill[:,0], hill[:,1], label='PH', linewidth=5, c='lightgrey', linestyle = '-')

ub=0.0569869/2 
print("Bulk velocity integrated over the inlet section =",ub)
fac=1/ub
pre=15
lw = 5 

for f in range(0,9):
    
    # Experimental data
    plt.scatter(pre*EXP_5600[f][:,3]+f,                    EXP_5600[f][:,0],               c='k',      linewidth=10, label='EXP', marker='.')
    
    # DNS results
    #plt.plot(fac*DNS_700[f][:,3]+f,                       DNS_700[f][:,0],                c='m',      linewidth=3,  label='Re_700')
    #plt.plot(fac*DNS_1400[f][:,3]+f,                      DNS_1400[f][:,0],               c='b',      linewidth=3,  label='Re_1400')
    #plt.plot(fac*DNS_2800[f][:,3]+f,                      DNS_2800[f][:,0],               c='lime',   linewidth=3,  label='Re_2800')
    plt.plot(pre*DNS_5600[f][:,3]+f,                       DNS_5600[f][:,0],               c='k',      linewidth=lw, label='Re_5600')
    #plt.plot(fac*LES_10595[f][:,3]+f,                     LES_10595[f][:,0],              c='k',      linewidth=3,  label='Re_10595')
    
    # DNS mapped onto RANS domain
    plt.plot(pre*fac*fac*DNS2RANS_R[f][:,1]+f,             DNS2RANS_R[f][:,0],             c='lime',   linewidth=3,  label='DNS2RANS') 
    
    # RANS solutions
    plt.plot(pre*fac*fac*RANS_R[f][:,1]+f,                 RANS_R[f][:,0],                 c='r',      linewidth=lw, label='RANS no inlet profiles') 
    plt.plot(pre*fac*fac*RANS_LaunderSharmaKE_R[f][:,1]+f, RANS_LaunderSharmaKE_R[f][:,0], c='b',      linewidth=lw, label='RANS_LaunderSharmaKE')
    plt.plot(pre*fac*fac*RANS_kOmegaSST_OF7_R[f][:,1]+f,   RANS_kOmegaSST_OF7_R[f][:,0],   c='m',      linewidth=lw, label='RANS_kOmegaSST')  
    
plt.xticks(np.arange(0, 10, step=1))
plt.ylabel("$y/H$ [-]")
plt.xlabel("$R_{xx}/u^2_{b} + x/H$ [-]")
plt.tight_layout()
#plt.legend(['top', 'bottom', 'Re_700', 'Re_1400', 'Re_2800', 'Re_5600', 'Re_10595'], loc='lower right')
#plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS'], loc='lower right')
plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS_kOmegaSST no inlet profiles', 'RANS_LaunderSharmaKE', 'RANS_kOmegaSST'], loc='lower right')
plt.grid()
plt.show()
plt.close()
# Out:
# Bulk velocity integrated over the inlet section = 0.02849345

# %%
plt.figure(figsize=(30,15), frameon=False)
plt.axhline(y = 3.05, xmin=0, xmax=9, color = 'lightgrey', linestyle = 'dotted', linewidth=5)
plt.plot(hill[:,0], hill[:,1], label='PH', linewidth=5, c='lightgrey', linestyle = '-')

ub=0.0569869/2 
print("Bulk velocity integrated over the inlet section =",ub)
fac=1/ub
pre=15
lw = 5 

for f in range(0,9):
    
    # Experimental data
    plt.scatter(pre*EXP_5600[f][:,4]+f,    EXP_5600[f][:,0],     c='k',      linewidth=10, label='EXP', marker='.')
    
    # DNS results
    #plt.plot(fac*DNS_700[f][:,4]+f,       DNS_700[f][:,0],      c='m',      linewidth=3,  label='Re_700')
    #plt.plot(fac*DNS_1400[f][:,4]+f,      DNS_1400[f][:,0],     c='b',      linewidth=3,  label='Re_1400')
    #plt.plot(fac*DNS_2800[f][:,4]+f,      DNS_2800[f][:,0],     c='lime',   linewidth=3,  label='Re_2800')
    plt.plot(pre*DNS_5600[f][:,4]+f,       DNS_5600[f][:,0],     c='k',      linewidth=lw, label='Re_5600')
    #plt.plot(fac*LES_10595[f][:,4]+f,     LES_10595[f][:,0],    c='k',      linewidth=3,  label='Re_10595')
    
    # DNS mapped onto RANS domain
    plt.plot(pre*fac*fac*DNS2RANS_R[f][:,4]+f, DNS2RANS_R[f][:,0],   c='lime',   linewidth=3,  label='DNS2RANS') 
    
    # RANS solutions
    plt.plot(pre*fac*fac*RANS_R[f][:,4]+f,     RANS_R[f][:,0],       c='r',      linewidth=lw, label='RANS no inlet profiles') 
    plt.plot(pre*fac*fac*RANS_LaunderSharmaKE_R[f][:,4]+f,     RANS_LaunderSharmaKE_R[f][:,0],       c='b',      linewidth=lw, label='RANS_LaunderSharmaKE')
    plt.plot(pre*fac*fac*RANS_kOmegaSST_OF7_R[f][:,4]+f,       RANS_kOmegaSST_OF7_R[f][:,0],         c='m',      linewidth=lw, label='RANS_kOmegaSST')  
       
plt.xticks(np.arange(0, 10, step=1))
plt.ylabel("$y/H$ [-]")
plt.xlabel("$R_{yy}/u^2_{b} + x/H$ [-]")
plt.tight_layout()
#plt.legend(['top', 'bottom', 'Re_700', 'Re_1400', 'Re_2800', 'Re_5600', 'Re_10595'], loc='lower right')
#plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS'], loc='lower right')
plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS_kOmegaSST no inlet profiles', 'RANS_LaunderSharmaKE', 'RANS_kOmegaSST'], loc='lower right')
plt.grid()
plt.show()
plt.close()
# Out:
# Bulk velocity integrated over the inlet section = 0.02849345

# %%
plt.figure(figsize=(30,15), frameon=False)
plt.axhline(y = 3.05, xmin=0, xmax=9, color = 'lightgrey', linestyle = 'dotted', linewidth=5)
plt.plot(hill[:,0], hill[:,1], label='PH', linewidth=5, c='lightgrey', linestyle = '-')

ub=0.0569869/2 
print("Bulk velocity integrated over the inlet section =",ub)
fac=1/ub
pre=15
lw = 5 

for f in range(0,9):
    
    # Experimental data
    plt.scatter(pre*EXP_5600[f][:,5]+f,    EXP_5600[f][:,0],     c='k',      linewidth=10, label='EXP', marker='.')
    
    # DNS results
    #plt.plot(fac*DNS_700[f][:,5]+f,       DNS_700[f][:,0],      c='m',      linewidth=3,  label='Re_700')
    #plt.plot(fac*DNS_1400[f][:,5]+f,      DNS_1400[f][:,0],     c='b',      linewidth=3,  label='Re_1400')
    #plt.plot(fac*DNS_2800[f][:,5]+f,      DNS_2800[f][:,0],     c='lime',   linewidth=3,  label='Re_2800')
    plt.plot(pre*DNS_5600[f][:,5]+f,       DNS_5600[f][:,0],     c='k',      linewidth=lw, label='Re_5600')
    #plt.plot(fac*LES_10595[f][:,5]+f,     LES_10595[f][:,0],    c='k',      linewidth=3,  label='Re_10595')
    
    # DNS mapped onto RANS domain
    plt.plot(pre*fac*fac*DNS2RANS_R[f][:,2]+f,             DNS2RANS_R[f][:,0],             c='lime',   linewidth=3,  label='DNS2RANS') 
    
    # RANS solutions
    plt.plot(pre*fac*fac*RANS_R[f][:,2]+f,                 RANS_R[f][:,0],                 c='r',      linewidth=lw, label='RANS no inlet profiles') 
    plt.plot(pre*fac*fac*RANS_LaunderSharmaKE_R[f][:,2]+f, RANS_LaunderSharmaKE_R[f][:,0], c='b',      linewidth=lw, label='RANS_LaunderSharmaKE')
    plt.plot(pre*fac*fac*RANS_kOmegaSST_OF7_R[f][:,2]+f,   RANS_kOmegaSST_OF7_R[f][:,0],   c='m',      linewidth=lw, label='RANS_kOmegaSST') 

plt.xticks(np.arange(0, 10, step=1))
plt.ylabel("$y/H$ [-]")
plt.xlabel("$R_{xy}/u^2_{b} + x/H$ [-]")
plt.tight_layout()
#plt.legend(['top', 'bottom', 'Re_700', 'Re_1400', 'Re_2800', 'Re_5600', 'Re_10595'], loc='lower right')
#plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS'], loc='lower right')
plt.legend(['top', 'bottom', 'EXP', 'DNS', 'DNS2RANS', 'RANS_kOmegaSST no inlet profiles', 'RANS_LaunderSharmaKE', 'RANS_kOmegaSST'], loc='lower right')
plt.grid()
plt.show()
plt.close()
# Out:
# Bulk velocity integrated over the inlet section = 0.02849345

# %%
plt.figure(figsize=(30,15), frameon=False)
plt.axhline(y = 3.05, xmin=0, xmax=9, color = 'lightgrey', linestyle = 'dotted', linewidth=5)
plt.plot(hill[:,0], hill[:,1], label='PH', linewidth=5, c='lightgrey', linestyle = '-')

ub=0.0569869/2 
print("Bulk velocity integrated over the inlet section =",ub)
fac=1/ub
pre=5
lw = 5 

for f in range(0,9):
    
    # Experimental data
    #plt.scatter(pre*EXP_5600[f][:,6]+f,    EXP_5600[f][:,0],     c='k',      linewidth=10, label='EXP', marker='.')
    
    # DNS results
    #plt.plot(fac*DNS_700[f][:,6]+f,       DNS_700[f][:,0],      c='m',      linewidth=3,  label='Re_700')
    #plt.plot(fac*DNS_1400[f][:,6]+f,      DNS_1400[f][:,0],     c='b',      linewidth=3,  label='Re_1400')
    #plt.plot(fac*DNS_2800[f][:,6]+f,      DNS_2800[f][:,0],     c='lime',   linewidth=3,  label='Re_2800')
    plt.plot(pre*DNS_5600[f][:,6]+f,       DNS_5600[f][:,0],     c='k',      linewidth=lw, label='Re_5600')
    #plt.plot(fac*LES_10595[f][:,6]+f,     LES_10595[f][:,0],    c='k',      linewidth=3,  label='Re_10595')
    
    # DNS mapped onto RANS domain
    #plt.plot(pre*fac*fac*DNS2RANS_K[f][:,1]+f, DNS2RANS_K[f][:,0],   c='lime',   linewidth=3,  label='DNS2RANS') 
    
    # RANS solutions
    plt.plot(pre*fac*fac*RANS_K[f][:,1]+f,     RANS_K[f][:,0],       c='r',      linewidth=lw, label='RANS no inlet profiles') 
    
plt.xticks(np.arange(0, 10, step=1))
plt.ylabel("$y/H$ [-]")
plt.xlabel("$k/u^2_{b} + x/H$ [-]")
plt.tight_layout()
#plt.legend(['top', 'bottom', 'Re_700', 'Re_1400', 'Re_2800', 'Re_5600', 'Re_10595'], loc='lower right')
plt.legend(['top', 'bottom', 'DNS', 'RANS_kOmegaSST no inlet profiles'], loc='lower right')
plt.grid()
plt.show()
plt.close()
# Out:
# Bulk velocity integrated over the inlet section = 0.02849345
