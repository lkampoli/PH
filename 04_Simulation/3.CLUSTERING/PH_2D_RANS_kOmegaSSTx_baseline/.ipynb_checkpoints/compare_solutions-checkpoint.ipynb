# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
# LES (reference data) solutions (https://turbmodels.larc.nasa.gov/Other_LES_Data/2Dhill_periodic/README_p_vel_and_turb_hill.txt)
################################

p00 = np.loadtxt('../../Re_10595/p00.txt',delimiter=',')
p06 = np.loadtxt('../../Re_10595/p06.txt',delimiter=',')
p11 = np.loadtxt('../../Re_10595/p11.txt',delimiter=',')
p12 = np.loadtxt('../../Re_10595/p12.txt',delimiter=',')
p13 = np.loadtxt('../../Re_10595/p13.txt',delimiter=',')

p111 = np.loadtxt('../../Re_10595/p111.txt',delimiter=',')
p222 = np.loadtxt('../../Re_10595/p222.txt',delimiter=',')
p333 = np.loadtxt('../../Re_10595/p333.txt',delimiter=',')
p444 = np.loadtxt('../../Re_10595/p444.txt',delimiter=',')
p555 = np.loadtxt('../../Re_10595/p555.txt',delimiter=',')
p666 = np.loadtxt('../../Re_10595/p666.txt',delimiter=',')
p777 = np.loadtxt('../../Re_10595/p777.txt',delimiter=',')
p888 = np.loadtxt('../../Re_10595/p888.txt',delimiter=',')

#hill_LES_avgresults = pd.read_csv('../../hill_LES_avgresults.csv')

# %%
# Fabian's solutions
####################
path = 'postProcessing/sets/20000/'

# Velocity profiles 
X0H_U = pd.read_csv(path+'X0H_U.csv')
X1H_U = pd.read_csv(path+'X1H_U.csv')
X2H_U = pd.read_csv(path+'X2H_U.csv')
X3H_U = pd.read_csv(path+'X3H_U.csv')
X4H_U = pd.read_csv(path+'X4H_U.csv')
X5H_U = pd.read_csv(path+'X5H_U.csv')
X6H_U = pd.read_csv(path+'X6H_U.csv')
X7H_U = pd.read_csv(path+'X7H_U.csv')
X8H_U = pd.read_csv(path+'X8H_U.csv')

# %%
# Ali's solutions
#################
path = '../PH_Cases/Mesh_120_by_130/steadyState_2D_Baseline_RANS_SST/postProcessing/sets/5000/'

# Velocity profiles 
X_2h_U = np.loadtxt(path+'X_2h_U.xy')
X_4h_U = np.loadtxt(path+'X_4h_U.xy')
X_6h_U = np.loadtxt(path+'X_6h_U.xy')
X_8h_U = np.loadtxt(path+'X_8h_U.xy')

# %%
# My solutions
##############

path = '/home/unimelb.edu.au/lcampoli/UoM/Testcases/PeriodicHill/02_Training/my_training_template_individual_jobs/running_pfac150_pop100_seed0/run_03723/PH_2D_RANS_kOmegaSSTx/postProcessing/sets/7714/'

# Velocity profiles 
my_X0H_U = pd.read_csv(path+'X0H_U.csv')
my_X1H_U = pd.read_csv(path+'X1H_U.csv')
my_X2H_U = pd.read_csv(path+'X2H_U.csv')
my_X3H_U = pd.read_csv(path+'X3H_U.csv')
my_X4H_U = pd.read_csv(path+'X4H_U.csv')
my_X5H_U = pd.read_csv(path+'X5H_U.csv')
my_X6H_U = pd.read_csv(path+'X6H_U.csv')
my_X7H_U = pd.read_csv(path+'X7H_U.csv')
my_X8H_U = pd.read_csv(path+'X8H_U.csv')

# %%
plt.figure(figsize=(30,15), frameon=False)
plt.scatter(X0H_U['U_0']+0, X0H_U['y'], label='Fabian_X0H')
plt.scatter(X1H_U['U_0']+1, X1H_U['y'], label='Fabian_X1H')
plt.scatter(X2H_U['U_0']+2, X2H_U['y'], label='Fabian_X2H')
plt.scatter(X3H_U['U_0']+3, X3H_U['y'], label='Fabian_X3H')
plt.scatter(X4H_U['U_0']+4, X4H_U['y'], label='Fabian_X4H')
plt.scatter(X5H_U['U_0']+5, X5H_U['y'], label='Fabian_X5H')
plt.scatter(X6H_U['U_0']+6, X6H_U['y'], label='Fabian_X6H')
plt.scatter(X7H_U['U_0']+7, X7H_U['y'], label='Fabian_X7H')
plt.scatter(X8H_U['U_0']+8, X8H_U['y'], label='Fabian_X8H')
#
plt.plot(p06[:,1]+0,   p06[:,0], label='ref_p06',  linewidth=3)
plt.plot(p111[:,1]+1, p111[:,0], label='ref_p111', linewidth=3)
plt.plot(p222[:,1]+2, p222[:,0], label='ref_p222', linewidth=3)
plt.plot(p333[:,1]+3, p333[:,0], label='ref_p333', linewidth=3)
plt.plot(p444[:,1]+4, p444[:,0], label='ref_p444', linewidth=3)
plt.plot(p555[:,1]+5, p555[:,0], label='ref_p555', linewidth=3)
plt.plot(p666[:,1]+6, p666[:,0], label='ref_p666', linewidth=3)
plt.plot(p777[:,1]+7, p777[:,0], label='ref_p777', linewidth=3)
plt.plot(p888[:,1]+8, p888[:,0], label='ref_p888', linewidth=3)
#
plt.scatter(X_2h_U[:,1]+2, X_2h_U[:,0], c='k', label='Ali_X_2h')
plt.scatter(X_4h_U[:,1]+4, X_4h_U[:,0], c='k', label='Ali_X_4h')
plt.scatter(X_6h_U[:,1]+6, X_6h_U[:,0], c='k', label='Ali_X_6h')
plt.scatter(X_8h_U[:,1]+8, X_8h_U[:,0], c='k', label='Ali_X_8h')
#
plt.plot(my_X0H_U['U_0']+0, my_X0H_U['y'], c='b', label='my_X_0h', linewidth=3, linestyle ='dashed')
plt.plot(my_X1H_U['U_0']+1, my_X1H_U['y'], c='b', label='my_X_1h', linewidth=3, linestyle ='dashed')
plt.plot(my_X2H_U['U_0']+2, my_X2H_U['y'], c='b', label='my_X_2h', linewidth=3, linestyle ='dashed')
plt.plot(my_X3H_U['U_0']+3, my_X3H_U['y'], c='b', label='my_X_2h', linewidth=3, linestyle ='dashed')
plt.plot(my_X4H_U['U_0']+4, my_X4H_U['y'], c='b', label='my_X_4h', linewidth=3, linestyle ='dashed')
plt.plot(my_X5H_U['U_0']+5, my_X5H_U['y'], c='b', label='my_X_5h', linewidth=3, linestyle ='dashed')
plt.plot(my_X6H_U['U_0']+6, my_X6H_U['y'], c='b', label='my_X_6h', linewidth=3, linestyle ='dashed')
plt.plot(my_X7H_U['U_0']+7, my_X7H_U['y'], c='b', label='my_X_7h', linewidth=3, linestyle ='dashed')
plt.plot(my_X8H_U['U_0']+8, my_X8H_U['y'], c='b', label='my_X_8h', linewidth=3, linestyle ='dashed')
#
plt.xlabel('X')
plt.ylabel('U')
#
plt.tight_layout()
plt.savefig('PH.pdf')
plt.grid()
plt.legend()
plt.show()
plt.close()
# Out:
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# ...
